# %% [markdown]
# # Chapter 1: Getting Started with SQL and BigQuery
#
# ### Core Concepts:
# * **BigQuery Hierarchy**: Projects contain Datasets, which contain Tables.
# * **Client**: Represents the connection to GCP BigQuery.
# * **Dataset**: A collection of tables (analogous to a database schema).
# * **Table**: Holds rows and columns of data, defined by a schema.
# * **Schema**: A list of fields describing columns (`name`, `field_type`, `mode`, `description`).
#
# Let's practice retrieving datasets, inspect a table's schema, and preview row data.

# %%
from google.cloud import bigquery

# 1. Initialize the client
client = bigquery.Client()

# %% [markdown]
# ## Task 1: Fetch the Chicago Crime Dataset
#
# We will pull the public dataset `chicago_crime` from the `bigquery-public-data` project.

# %%
# Reference the dataset
dataset_ref = client.dataset("chicago_crime", project="bigquery-public-data")

# Fetch the dataset metadata
dataset = client.get_dataset(dataset_ref)

print(f"Successfully fetched dataset '{dataset.dataset_id}' from project '{dataset.project}'")
# Out:
# Successfully fetched dataset 'chicago_crime' from project 'bigquery-public-data'

# %% [markdown]
# ## Task 2: List Tables in the Dataset
#
# Now let's list the tables contained in this dataset.

# %%
# List all tables in the dataset
tables = list(client.list_tables(dataset))

print(f"Number of tables in the dataset: {len(tables)}")
for t in tables:
    print(f" - Table Name: {t.table_id}")
# Out:
# Number of tables in the dataset: 1
#  - Table Name: crime

# %% [markdown]
# ## Task 3: Inspect Table Schema
#
# Let's fetch the main `crime` table and look at its structure (its schema).

# %%
# Reference the 'crime' table
table_ref = dataset_ref.table("crime")

# Fetch the table object
table = client.get_table(table_ref)

# Print out table schema fields
print("Table Schema:")
for field in table.schema:
    print(f"Field: {field.name:<20} | Type: {field.field_type:<10} | Mode: {field.mode:<10}")
# Out:
# Table Schema:
# Field: unique_key           | Type: INTEGER    | Mode: REQUIRED
# Field: case_number          | Type: STRING     | Mode: NULLABLE
# Field: date                 | Type: TIMESTAMP  | Mode: NULLABLE
# Field: block                | Type: STRING     | Mode: NULLABLE
# Field: iucr                 | Type: STRING     | Mode: NULLABLE
# Field: primary_type         | Type: STRING     | Mode: NULLABLE
# Field: description          | Type: STRING     | Mode: NULLABLE
# Field: location_description | Type: STRING     | Mode: NULLABLE
# Field: arrest               | Type: BOOLEAN    | Mode: NULLABLE
# Field: domestic             | Type: BOOLEAN    | Mode: NULLABLE
# Field: beat                 | Type: INTEGER    | Mode: NULLABLE
# Field: district             | Type: INTEGER    | Mode: NULLABLE
# Field: ward                 | Type: INTEGER    | Mode: NULLABLE
# Field: community_area       | Type: INTEGER    | Mode: NULLABLE
# Field: fbi_code             | Type: STRING     | Mode: NULLABLE
# Field: x_coordinate         | Type: FLOAT      | Mode: NULLABLE
# Field: y_coordinate         | Type: FLOAT      | Mode: NULLABLE
# Field: year                 | Type: INTEGER    | Mode: NULLABLE
# Field: updated_on           | Type: TIMESTAMP  | Mode: NULLABLE
# Field: latitude             | Type: FLOAT      | Mode: NULLABLE
# Field: longitude            | Type: FLOAT      | Mode: NULLABLE
# Field: location             | Type: STRING     | Mode: NULLABLE

# %% [markdown]
# ## Task 4: Preview Data as a Pandas DataFrame
#
# To avoid scanning large amounts of data (which costs money/quota), we can use `list_rows` to fetch a small preview of the table's rows directly without running a SQL query.

# %%
# Preview the first 5 rows of the 'crime' table
preview = client.list_rows(table, max_results=5).to_dataframe()

# Display the DataFrame
preview
# Out:
#    unique_key case_number                      date                   block  \
# 0        1086     G560545 2001-09-18 13:15:00+00:00    001XX N JEFFERSON ST
# 1       24378    JC113580 2019-01-11 22:30:00+00:00  000XX E IDA B WELLS DR
# 2     8747633    HV422434 2012-08-09 03:00:00+00:00    001XX N MICHIGAN AVE
# 3    13624909    JH461271 2024-10-08 20:30:00+00:00      002XX N WABASH AVE
# 4     1837474     G672156 2001-11-07 22:34:39+00:00        002XX S CANAL ST
#
#    iucr             primary_type                     description  \
# 0  0110                 HOMICIDE             FIRST DEGREE MURDER
# 1  0110                 HOMICIDE             FIRST DEGREE MURDER
# 2  0265      CRIM SEXUAL ASSAULT               AGGRAVATED: OTHER
# 3  0265  CRIMINAL SEXUAL ASSAULT              AGGRAVATED - OTHER
# 4  0312                  ROBBERY  ARMED:KNIFE/CUTTING INSTRUMENT
#
#   location_description  arrest  domestic  ...  ward  community_area  fbi_code  \
# 0                 AUTO    True      True  ...    42              28       01A
# 1               STREET    True     False  ...     4              32       01A
# 2                ALLEY   False     False  ...    42              32        02
# 3        BAR OR TAVERN   False     False  ...    42              32        02
# 4             SIDEWALK   False     False  ...  <NA>            <NA>        03
#
#    x_coordinate y_coordinate  year                updated_on   latitude  \
# 0     1172311.0    1900981.0  2001 2022-09-19 15:41:05+00:00  41.883739
# 1     1176730.0    1898080.0  2019 2022-09-01 15:42:17+00:00  41.875679
# 2     1177272.0    1901512.0  2012 2018-02-10 15:50:01+00:00  41.885085
# 3     1176773.0    1901888.0  2024 2025-05-17 15:40:52+00:00  41.886128
# 4     1173137.0    1899241.0  2001 2015-08-17 15:03:40+00:00  41.878946
#
#    longitude                       location
# 0 -87.642714  (41.883738563, -87.642713824)
# 1 -87.626575   (41.875679322, -87.62657476)
# 2 -87.624481  (41.885084656, -87.624480684)
# 3 -87.626302  (41.886127716, -87.626301698)
# 4 -87.639732  (41.878945611, -87.639732344)
#
# [5 rows x 22 columns]
